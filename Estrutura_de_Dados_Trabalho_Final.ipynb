# %% [markdown]
# <a href="https://colab.research.google.com/github/fgsantosti/estruturadedados/blob/main/Estrutura_de_Dados_Trabalho_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabalho Final - Estrutura de Dados
#
#
# Para desenvolver o projeto final sobre grafos, você precisará criar uma estrutura de dados para representar o grafo usando listas de adjacências e implementar uma interface de usuário que permita interação com o sistema.
#
# #### Grafo
# Uma classe `Grafo` pode ser usada para representar o grafo, contendo uma lista de adjacências e métodos para manipular o grafo.
#
# ```java
# import java.util.*;
#
# class Grafo {
#     private Map<Integer, List<Aresta>> adjacencias;
#     private int numVertices;
#
#     public Grafo() {
#         adjacencias = new HashMap<>();
#         numVertices = 0;
#     }
#
#     public void inserirVertice(int id) {
#         if (!adjacencias.containsKey(id)) {
#             adjacencias.put(id, new ArrayList<>());
#             numVertices++;
#         }
#     }
#
#     public void inserirAresta(int origem, int destino, int peso) {
#         adjacencias.get(origem).add(new Aresta(destino, peso));
#         adjacencias.get(destino).add(new Aresta(origem, peso)); // Como o grafo é não direcionado
#     }
#
#     public void removerVertice(int id) {
#         adjacencias.values().forEach(list -> list.removeIf(aresta -> aresta.destino == id));
#         adjacencias.remove(id);
#         numVertices--;
#     }
#
#     public void removerAresta(int origem, int destino) {
#         adjacencias.get(origem).removeIf(aresta -> aresta.destino == destino);
#         adjacencias.get(destino).removeIf(aresta -> aresta.destino == origem);
#     }
#
#     // Outros métodos para as funcionalidades restantes...
# }
# ```
#
# #### Aresta
# Uma classe `Aresta` pode ser usada para representar as arestas, contendo o destino e o peso.
#
# ```java
# class Aresta {
#     int destino;
#     int peso;
#
#     public Aresta(int destino, int peso) {
#         this.destino = destino;
#         this.peso = peso;
#     }
# }
# ```
#
# ### Funcionalidades do Sistema
#
# 1. **Inserir Vértice**: Adicionar um novo vértice ao grafo.
# 2. **Inserir Aresta**: Adicionar uma aresta entre dois vértices com um peso específico.
# 3. **Remover Vértice**: Remover um vértice e todas as arestas associadas a ele.
# 4. **Remover Aresta**: Remover uma aresta específica entre dois vértices.
# 5. **Visualizar Grafo**: Exibir a representação do grafo, podendo ser através de texto ou visualização gráfica.
# 6. **Informar Grau de um Vértice**: Calcular e exibir o grau de um vértice específico.
# 7. **Verificar se o Grafo é Conexo**: Verificar se há um caminho entre todos os pares de vértices.
# 8. **Converter para Matriz de Adjacência**: Transformar a lista de adjacências em uma matriz de adjacências.
# 9. **Caminhamento em Amplitude (BFS)**: Implementar o algoritmo de Busca em Largura.
# 10. **Caminhamento em Profundidade (DFS)**: Implementar o algoritmo de Busca em Profundidade.
# 11. **Caminho Mínimo (Dijkstra)**: Implementar o algoritmo de Dijkstra para encontrar o caminho mais curto entre dois vértices.
# 12. **Árvore Geradora Mínima (Prim)**: Implementar o algoritmo de Prim para encontrar a árvore geradora mínima do grafo.
#
# ### Interface do Usuário
#
# Você pode usar a linha de comando para criar um menu simples que permita ao usuário interagir com o sistema, ou optar por uma interface gráfica usando bibliotecas como Swing (para Java) ou GTK (para C).
#
# ### Documentação e Vídeo
# - **GitHub:**
#   - Código-fonte organizado com instruções de instalação e uso.
#   - README detalhado com visão geral do projeto, funcionalidades, tecnologias utilizadas, e links para recursos adicionais.
#
# - **Vídeo Explicativo:**
#   - Apresentação do aplicativo, funcionalidades principais, e uma demonstração de uso.
#
# Se precisar de ajuda com alguma parte específica do projeto, como a implementação de algum algoritmo ou detalhes de estrutura de dados, sinta-se à vontade para perguntar!

# %% [markdown]
# Aqui estão algumas representações visuais que poderiam fazer parte do sistema de grafos:
#
#
# ![estrutura_dados_aplicacao_final.png](data:image/png;base64,...)
#
#
# 1. **Representação do Grafo**: Exibe os vértices e arestas com pesos, ajudando a visualizar a estrutura e conexões do grafo.
#
# 2. **Matriz de Adjacência**: Mostra a matriz de adjacência correspondente ao grafo, com os valores dos pesos das arestas.
#
# 3. **Caminhamento em Amplitude (BFS)**: Ilustra o resultado de um caminhamento em amplitude, começando de um vértice específico.
#
# 4. **Caminho Mínimo (Dijkstra)**: Demonstra o caminho mais curto entre dois vértices, destacando as arestas que compõem esse caminho.
#
# Essas visualizações são úteis para entender a estrutura e as propriedades do grafo, além de serem uma ótima maneira de apresentar os resultados de algoritmos aplicados ao grafo.
